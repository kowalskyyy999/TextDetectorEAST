# %%
from lib.utils import *

import os
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
from sklearn.model_selection import train_test_split

# %%
print(get_score_geo)
# Out:
# <function get_score_geo at 0x7f01820fbe50>

# %%
path = '/home/kowlsss/Desktop/tutorial/torch/east/data/MSRA-TD500'
train_path = os.path.join(path, 'train')

train_df = extract2df(train_path)
train_df.drop_duplicates(['image', 'index', 'difficult'], inplace=True)

train_df['corners'] = train_df.apply(lambda df: get_corners([df.x, df.y, df.w, df.h]), axis=1)
train_df['new_corners'] = train_df.apply(lambda df: move_points(df.corners, df.cx, df.cy, df.degree), axis=1)

image_unique = train_df['image'].unique()
ids = np.random.randint(len(image_unique))

image_name = image_unique[ids]
image = cv2.imread(os.path.join(train_path, f'{image_name}.JPG'))
H, W, _ = image.shape
img = Image.fromarray(image)

mask = np.zeros((H, W))
df_select = train_df[train_df['image'] == image_name]

plt.figure(figsize=(15, 12))
fig, ax = plt.subplots(3, 1, figsize=(15, 20))

vertices = []
angles = []
scale = 0.25
length = (W, H)

for df in df_select.values:
    points = np.array(df[-1]).reshape((-1, 1, 2))
    cv2.polylines(image, [points], True, (0, 0, 255), 5)
    
    mask = get_mask(mask, points)
    
    src_pts = points.astype('float32')
    dst_pts = np.array([[0, df[6] - 1],
                        [0, 0],
                        [df[5] - 1, 0],
                        [df[5] - 1, df[6] - 1]], dtype="float32")
    
    M = cv2.getPerspectiveTransform(src_pts, dst_pts)
    warped = cv2.warpPerspective(image, M, (df[6], df[5]))
    
    angles.append(df[8])
    vertices.append(get_vertices(df[-1]))
    
print(vertices, angles, length)

temp_masks, image_resize = get_score_geo(image, vertices, angles, scale, length)

ax[0].imshow(image)
ax[1].imshow(mask)
ax[2].imshow(temp_masks)

plt.show()
# Out:
# [array([ 544,   11, 1461,  292, 1401,  488,  484,  207]), array([ 469,  311, 1357,  549, 1319,  689,  432,  451]), array([1227,  684, 1487,  749, 1469,  822, 1209,  757])] [73.0, 75.0, 76.0] (1600, 1200)

# %%
image_resize.shape
# Out:
# (324, 432, 5)

# %% [markdown]
# ## Create Dataset

# %%
class MSRADataset(Dataset):
    def __init__(self, 
                 path, 
                 test_size=None, 
                 img_resize=(1600, 1200), 
                 transform=None,  
                 scale=0.25):
        
        self.path = path
        
        self.df = extract2df(path)
        self.df.drop_duplicates(['image', 'index', 'difficult'], inplace=True)
        
        self.image_ids = self.df.image.unique()
        self.test_size = test_size
        self.img_resize = img_resize
        self.transform = transform
        
    def __len__(self):
        return len(self.image_ids)
    
    def __getitem__(self, idx):
        ids = self.image_ids[idx]
        image = cv2.imread(os.path.join(self.path, f'{ids}.JPG')) # Load the image
        
        image_resize = cv2.resize(image, self.img_resize) # Resize image
        
        data = self.df[self.df['image'] == ids] # filtering data by image ids
        
        vertices, angles, mask = self.preprocessing(image, image_resize, data) # preprocessing to get vertices
        
        image = Image.fromarray(image_resize) # Convert to PIL
        
        print(vertices, angles)
        
        score_map, geo_map = get_score_geo(image, vertices, angles, self.scale, self.img_resize) # get ground truth
        
        score_tensor = torch.Tensor(score_map).permute(2, 0, 1)
        geo_tensor = torch.Tensor(geo_map).permute(2, 0, 1)
        mask_tensor = torch.Tensor(Image.fromarray(mask))
        
        if transform:
            image = self.transform(img_resize)
                   
        return image, mask_tensor, score_tensor, geo_tensor
        
    def preprocessing(self, img, img_resize, data):
        h, w, _ = img.shape
        h_r, w_r, _ = img_resize.shape
        mask = np.zeros((h_r, w_r))
        
        vertices = []
        angles = []
        
        for d in data.values:
            x, y, w, h = Resize(d, w, h, w_r, h_r)
            cx = int(w) // 2 + int(x)
            cy = int(h) // 2 + int(y)
            
            corner = get_corners([x, y, w, h])
            corner = move_points(corner, cx, cy, df[8])
            
            points = np.array(corner).reshape((-1, 1, 2))
            
            mask = get_mask(mask, points)
            
            vertices.append(get_vertices(corner))
            angles.append(df[8])
            
        return vertices, angles, mask

transform = T.Compose([
    T.ToTensor()
])
train_dataset = MSRADataset(path=train_path, transform=transform)
for data in train_dataset:
    print(data)
    break
# Out:
# [array([1271,  211, 1553,  225, 1549,  301, 1267,  287]), array([ 5293, 10740,  6987, 10829,  6923, 12060,  5229, 11971]), array([1273, 1053, 1536, 1067, 1532, 1144, 1269, 1130])] [87.0, 87.0, 87.0]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_5201/1842382580.py in <module>
#      74 ])
#      75 train_dataset = MSRADataset(path=train_path, transform=transform)
# ---> 76 for data in train_dataset:
#      77     print(data)
#      78     break
#
# /tmp/ipykernel_5201/1842382580.py in __getitem__(self, idx)
#      34         print(vertices, angles)
#      35
# ---> 36         score_map, geo_map = get_score_geo(image, vertices, angles, self.scale, self.img_resize) # get ground truth
#      37
#      38         score_tensor = torch.Tensor(score_map).permute(2, 0, 1)
#
# ...

# %%
def resize(df, w, h, w_r, h_r):
    x = int(np.round(df[3] * w_r / w))
    y = int(np.round(df[4] * h_r / h))
    w = int(np.round(df[5] * w_r / w))
    h = int(np.round(df[6] * h_r / h))
    
    return x, y, w, h

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/jarvis/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/jarvis/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/jarvis/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'image_id'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
